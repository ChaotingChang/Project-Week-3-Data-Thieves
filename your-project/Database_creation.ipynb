# %%
from sqlalchemy import create_engine
import pymysql
import pandas as pd

# %%
driver = "mysql+pymysql:"
user = "root"
password = "ironhack"
ip = "35.188.185.234"
database = "Project_3"

# %%
connection_string = f"{driver}//{user}:{password}@{ip}/{database}"
engine = create_engine(connection_string)

# %%
query_year = """
CREATE TABLE year(
id INT(17) NOT NULL AUTO_INCREMENT,
year INT(4),

PRIMARY KEY(id)
);
"""

# %%
years = pd.read_sql(query_year, engine)

# %%
query_country = """
CREATE TABLE country(
id INT(17) NOT NULL AUTO_INCREMENT,
country VARCHAR(25),

PRIMARY KEY(id)
);
"""

# %%
countries = pd.read_sql(query_country, engine)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/result.py in _fetchall_impl(self)
#    1162         try:
# -> 1163             return self.cursor.fetchall()
#    1164         except AttributeError:
#
# AttributeError: 'NoneType' object has no attribute 'fetchall'
#
# During handling of the above exception, another exception occurred:
#
# ResourceClosedError                       Traceback (most recent call last)
# <ipython-input-29-95986d861ec0> in <module>
# ----> 1 countries = pd.read_sql(query_country, engine)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     395             sql, index_col=index_col, params=params,
#     396             coerce_float=coerce_float, parse_dates=parse_dates,
# --> 397             chunksize=chunksize)
#     398
#     399
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize)
#    1106                                         parse_dates=parse_dates)
#    1107         else:
# -> 1108             data = result.fetchall()
#    1109             frame = _wrap_result(data, columns, index_col=index_col,
#    1110                                  coerce_float=coerce_float,
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/result.py in fetchall(self)
#    1216         except BaseException as e:
#    1217             self.connection._handle_dbapi_exception(
# -> 1218                 e, None, None, self.cursor, self.context
#    1219             )
#    1220
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1466                 util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1467             else:
# -> 1468                 util.reraise(*exc_info)
#    1469
#    1470         finally:
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     127         if value.__traceback__ is not tb:
#     128             raise value.with_traceback(tb)
# --> 129         raise value
#     130
#     131     def u(s):
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/result.py in fetchall(self)
#    1211
#    1212         try:
# -> 1213             l = self.process_rows(self._fetchall_impl())
#    1214             self._soft_close()
#    1215             return l
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/result.py in _fetchall_impl(self)
#    1163             return self.cursor.fetchall()
#    1164         except AttributeError:
# -> 1165             return self._non_result([])
#    1166
#    1167     def _non_result(self, default):
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/result.py in _non_result(self, default)
#    1168         if self._metadata is None:
#    1169             raise exc.ResourceClosedError(
# -> 1170                 "This result object does not return rows. "
#    1171                 "It has been closed automatically."
#    1172             )
#
# ResourceClosedError: This result object does not return rows. It has been closed automatically.

# %%
query_happiness = """
CREATE TABLE happiness(
id INT(17) NOT NULL AUTO_INCREMENT,
id_year INT(17),
id_country INT(17),
score FLOAT,

PRIMARY KEY(id),
FOREIGN KEY(id_year) REFERENCES year(id),
FOREIGN KEY(id_country) REFERENCES country(id)
);
"""

# %%
happiness = pd.read_sql(query_happiness, engine)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/result.py in _fetchall_impl(self)
#    1162         try:
# -> 1163             return self.cursor.fetchall()
#    1164         except AttributeError:
#
# AttributeError: 'NoneType' object has no attribute 'fetchall'
#
# During handling of the above exception, another exception occurred:
#
# ResourceClosedError                       Traceback (most recent call last)
# <ipython-input-41-91a0250ba3f8> in <module>
# ----> 1 happiness = pd.read_sql(query_happiness, engine)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     395             sql, index_col=index_col, params=params,
#     396             coerce_float=coerce_float, parse_dates=parse_dates,
# --> 397             chunksize=chunksize)
#     398
#     399
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize)
#    1106                                         parse_dates=parse_dates)
#    1107         else:
# -> 1108             data = result.fetchall()
#    1109             frame = _wrap_result(data, columns, index_col=index_col,
#    1110                                  coerce_float=coerce_float,
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/result.py in fetchall(self)
#    1216         except BaseException as e:
#    1217             self.connection._handle_dbapi_exception(
# -> 1218                 e, None, None, self.cursor, self.context
#    1219             )
#    1220
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1466                 util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1467             else:
# -> 1468                 util.reraise(*exc_info)
#    1469
#    1470         finally:
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     127         if value.__traceback__ is not tb:
#     128             raise value.with_traceback(tb)
# --> 129         raise value
#     130
#     131     def u(s):
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/result.py in fetchall(self)
#    1211
#    1212         try:
# -> 1213             l = self.process_rows(self._fetchall_impl())
#    1214             self._soft_close()
#    1215             return l
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/result.py in _fetchall_impl(self)
#    1163             return self.cursor.fetchall()
#    1164         except AttributeError:
# -> 1165             return self._non_result([])
#    1166
#    1167     def _non_result(self, default):
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/result.py in _non_result(self, default)
#    1168         if self._metadata is None:
#    1169             raise exc.ResourceClosedError(
# -> 1170                 "This result object does not return rows. "
#    1171                 "It has been closed automatically."
#    1172             )
#
# ResourceClosedError: This result object does not return rows. It has been closed automatically.

# %%
query_elections = """
CREATE TABLE elections(
id INT(17) NOT NULL AUTO_INCREMENT,
id_year INT(17),
id_country INT(17),
proportion_votes FLOAT,
extreme_type VARCHAR(30),

PRIMARY KEY(id),
FOREIGN KEY(id_year) REFERENCES year(id),
FOREIGN KEY(id_country) REFERENCES country(id)
);
"""

# %%
elections = pd.read_sql(query_elections, engine)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/result.py in _fetchall_impl(self)
#    1162         try:
# -> 1163             return self.cursor.fetchall()
#    1164         except AttributeError:
#
# AttributeError: 'NoneType' object has no attribute 'fetchall'
#
# During handling of the above exception, another exception occurred:
#
# ResourceClosedError                       Traceback (most recent call last)
# <ipython-input-43-d15f1eba8692> in <module>
# ----> 1 elections = pd.read_sql(query_elections, engine)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     395             sql, index_col=index_col, params=params,
#     396             coerce_float=coerce_float, parse_dates=parse_dates,
# --> 397             chunksize=chunksize)
#     398
#     399
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize)
#    1106                                         parse_dates=parse_dates)
#    1107         else:
# -> 1108             data = result.fetchall()
#    1109             frame = _wrap_result(data, columns, index_col=index_col,
#    1110                                  coerce_float=coerce_float,
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/result.py in fetchall(self)
#    1216         except BaseException as e:
#    1217             self.connection._handle_dbapi_exception(
# -> 1218                 e, None, None, self.cursor, self.context
#    1219             )
#    1220
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1466                 util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1467             else:
# -> 1468                 util.reraise(*exc_info)
#    1469
#    1470         finally:
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     127         if value.__traceback__ is not tb:
#     128             raise value.with_traceback(tb)
# --> 129         raise value
#     130
#     131     def u(s):
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/result.py in fetchall(self)
#    1211
#    1212         try:
# -> 1213             l = self.process_rows(self._fetchall_impl())
#    1214             self._soft_close()
#    1215             return l
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/result.py in _fetchall_impl(self)
#    1163             return self.cursor.fetchall()
#    1164         except AttributeError:
# -> 1165             return self._non_result([])
#    1166
#    1167     def _non_result(self, default):
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/result.py in _non_result(self, default)
#    1168         if self._metadata is None:
#    1169             raise exc.ResourceClosedError(
# -> 1170                 "This result object does not return rows. "
#    1171                 "It has been closed automatically."
#    1172             )
#
# ResourceClosedError: This result object does not return rows. It has been closed automatically.

# %%
query_tables = """
SHOW TABLES
"""

db_tables = pd.read_sql(query_tables, engine)
db_tables
# Out:
#   Tables_in_Project_3
# 0             country
# 1           elections
# 2           happiness
# 3                year

# %% [markdown]
# ### Writing the code to update existing tables once we have dataframes ready

# %%
happiness_all = pd.read_csv("../Data/happiness_all.csv")

# %%
happiness_all.to_sql("happiness", con=engine, if_exists="append", index=False)

#To check here whether this has been successful or not, below code.
#engine.execute("SELECT * FROM happiness").fetchall()
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1223                     self.dialect.do_executemany(
# -> 1224                         cursor, statement, parameters, context
#    1225                     )
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py in do_executemany(self, cursor, statement, parameters, context)
#     131     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 132         rowcount = cursor.executemany(statement, parameters)
#     133         if context is not None:
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/cursors.py in executemany(self, query, args)
#     196                                          self.max_stmt_length,
# --> 197                                          self._get_db().encoding)
#     198
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/cursors.py in _do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     233             sql += v
# --> 234         rows += self.execute(sql + postfix)
#     235         self.rowcount = rows
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/cursors.py in execute(self, query, args)
#     169
# --> 170         result = self._query(query)
#     171         self._executed = query
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/cursors.py in _query(self, q)
#     327         self._clear_result()
# --> 328         conn.query(q)
#     329         self._do_get_result()
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/connections.py in query(self, sql, unbuffered)
#     516         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 517         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     518         return self._affected_rows
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/connections.py in _read_query_result(self, unbuffered)
#     731             result = MySQLResult(self)
# --> 732             result.read()
#     733         self._result = result
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/connections.py in read(self)
#    1074         try:
# -> 1075             first_packet = self.connection._read_packet()
#    1076
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#     683         packet = packet_type(buff, self.encoding)
# --> 684         packet.check_error()
#     685         return packet
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/protocol.py in check_error(self)
#     219             if DEBUG: print("errno =", errno)
# --> 220             err.raise_mysql_exception(self._data)
#     221
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/err.py in raise_mysql_exception(data)
#     108     errorclass = error_map.get(errno, InternalError)
# --> 109     raise errorclass(errno, errval)
#
# InternalError: (1054, "Unknown column 'Unnamed: 0' in 'field list'")
#
# The above exception was the direct cause of the following exception:
#
# InternalError                             Traceback (most recent call last)
# <ipython-input-7-9dab7c009f7b> in <module>
# ----> 1 happiness_all.to_sql("happiness", con=engine, if_exists="append", index=False)
#       2
#       3 #To check here whether this has been successful or not, below code.
#       4 #engine.execute("SELECT * FROM happiness").fetchall()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2529         sql.to_sql(self, name, con, schema=schema, if_exists=if_exists,
#    2530                    index=index, index_label=index_label, chunksize=chunksize,
# -> 2531                    dtype=dtype, method=method)
#    2532
#    2533     def to_pickle(self, path, compression='infer',
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     458     pandas_sql.to_sql(frame, name, if_exists=if_exists, index=index,
#     459                       index_label=index_label, schema=schema,
# --> 460                       chunksize=chunksize, dtype=dtype, method=method)
#     461
#     462
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1172                          schema=schema, dtype=dtype)
#    1173         table.create()
# -> 1174         table.insert(chunksize, method=method)
#    1175         if (not name.isdigit() and not name.islower()):
#    1176             # check for potentially case sensitivity issues (GH7815)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in insert(self, chunksize, method)
#     684
#     685                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 686                 exec_insert(conn, keys, chunk_iter)
#     687
#     688     def _query_iterator(self, result, chunksize, columns, coerce_float=True,
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in _execute_insert(self, conn, keys, data_iter)
#     597         """
#     598         data = [dict(zip(keys, row)) for row in data_iter]
# --> 599         conn.execute(self.table.insert(), data)
#     600
#     601     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in execute(self, object_, *multiparams, **params)
#     986             raise exc.ObjectNotExecutableError(object_)
#     987         else:
# --> 988             return meth(self, multiparams, params)
#     989
#     990     def _execute_function(self, func, multiparams, params):
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/sql/elements.py in _execute_on_connection(self, connection, multiparams, params)
#     285     def _execute_on_connection(self, connection, multiparams, params):
#     286         if self.supports_execution:
# --> 287             return connection._execute_clauseelement(self, multiparams, params)
#     288         else:
#     289             raise exc.ObjectNotExecutableError(self)
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1105             distilled_params,
#    1106             compiled_sql,
# -> 1107             distilled_params,
#    1108         )
#    1109         if self._has_events or self.engine._has_events:
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1246         except BaseException as e:
#    1247             self._handle_dbapi_exception(
# -> 1248                 e, statement, parameters, cursor, context
#    1249             )
#    1250
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1464                 util.raise_from_cause(newraise, exc_info)
#    1465             elif should_wrap:
# -> 1466                 util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1467             else:
#    1468                 util.reraise(*exc_info)
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_from_cause(exception, exc_info)
#     381     exc_type, exc_value, exc_tb = exc_info
#     382     cause = exc_value if exc_value is not exception else None
# --> 383     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     384
#     385
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     126             value.__cause__ = cause
#     127         if value.__traceback__ is not tb:
# --> 128             raise value.with_traceback(tb)
#     129         raise value
#     130
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1222                 if not evt_handled:
#    1223                     self.dialect.do_executemany(
# -> 1224                         cursor, statement, parameters, context
#    1225                     )
#    1226             elif not parameters and context.no_parameters:
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py in do_executemany(self, cursor, statement, parameters, context)
#     130
#     131     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 132         rowcount = cursor.executemany(statement, parameters)
#     133         if context is not None:
#     134             context._rowcount = rowcount
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/cursors.py in executemany(self, query, args)
#     195             return self._do_execute_many(q_prefix, q_values, q_postfix, args,
#     196                                          self.max_stmt_length,
# --> 197                                          self._get_db().encoding)
#     198
#     199         self.rowcount = sum(self.execute(query, arg) for arg in args)
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/cursors.py in _do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     232                 sql += b','
#     233             sql += v
# --> 234         rows += self.execute(sql + postfix)
#     235         self.rowcount = rows
#     236         return rows
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/cursors.py in execute(self, query, args)
#     168         query = self.mogrify(query, args)
#     169
# --> 170         result = self._query(query)
#     171         self._executed = query
#     172         return result
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/cursors.py in _query(self, q)
#     326         self._last_executed = q
#     327         self._clear_result()
# --> 328         conn.query(q)
#     329         self._do_get_result()
#     330         return self.rowcount
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/connections.py in query(self, sql, unbuffered)
#     515                 sql = sql.encode(self.encoding, 'surrogateescape')
#     516         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 517         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     518         return self._affected_rows
#     519
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/connections.py in _read_query_result(self, unbuffered)
#     730         else:
#     731             result = MySQLResult(self)
# --> 732             result.read()
#     733         self._result = result
#     734         if result.server_status is not None:
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/connections.py in read(self)
#    1073     def read(self):
#    1074         try:
# -> 1075             first_packet = self.connection._read_packet()
#    1076
#    1077             if first_packet.is_ok_packet():
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#     682
#     683         packet = packet_type(buff, self.encoding)
# --> 684         packet.check_error()
#     685         return packet
#     686
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/protocol.py in check_error(self)
#     218             errno = self.read_uint16()
#     219             if DEBUG: print("errno =", errno)
# --> 220             err.raise_mysql_exception(self._data)
#     221
#     222     def dump(self):
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/err.py in raise_mysql_exception(data)
#     107         errval = data[3:].decode('utf-8', 'replace')
#     108     errorclass = error_map.get(errno, InternalError)
# --> 109     raise errorclass(errno, errval)
#
# InternalError: (pymysql.err.InternalError) (1054, "Unknown column 'Unnamed: 0' in 'field list'")
# [SQL: INSERT INTO happiness (`Unnamed: 0`, `Country`, `Year`, `Score`, `GDP`, `Social support`, `Healthy life expectancy`, `Freedom`, `Generosity`, `Perceptions of corruption`, `Confidence in national government`) VALUES (%(Unnamed: 0)s, %(Country)s, %(Year)s, %(Score)s, %(GDP)s, %(Social support)s, %(Healthy life expectancy)s, %(Freedom)s, %(Generosity)s, %(Perceptions of corruption)s, %(Confidence in national government)s)]
# [parameters: ({'Unnamed: 0': 0, 'Country': 'Austria', 'Year': 2006, 'Score': 7.1222114560000005, 'GDP': 10.64822578, 'Social support': 0.936350405, 'Healthy life expectancy': 70.01869965, 'Freedom': 0.9413823490000001, 'Generosity': None, 'Perceptions of corruption': None, 'Confidence in national government': 0.497037798}, {'Unnamed: 0': 1, 'Country': 'Austria', 'Year': 2008, 'Score': 7.180953979, 'GDP': 10.69278336, 'Social support': 0.9345927829999999, 'Healthy life expectancy': 70.5018692, 'Freedom': 0.879069269, 'Generosity': None, 'Perceptions of corruption': None, 'Confidence in national government': 0.257242203}, {'Unnamed: 0': 2, 'Country': 'Austria', 'Year': 2010, 'Score': 7.302678585, 'GDP': 10.66813183, 'Social support': 0.9141933320000001, 'Healthy life expectancy': 70.63227844, 'Freedom': 0.8959797620000001, 'Generosity': None, 'Perceptions of corruption': None, 'Confidence in national government': 0.48644661899999997}, {'Unnamed: 0': 3, 'Country': 'Austria', 'Year': 2011, 'Score': 7.470512867, 'GDP': 10.69245338, 'Social support': 0.944156826, 'Healthy life expectancy': 70.98503876, 'Freedom': 0.9393556120000001, 'Generosity': None, 'Perceptions of corruption': None, 'Confidence in national government': 0.406920105}, {'Unnamed: 0': 4, 'Country': 'Austria', 'Year': 2012, 'Score': 7.400688647999999, 'GDP': 10.69543934, 'Social support': 0.9451423879999999, 'Healthy life expectancy': 70.94441223, 'Freedom': 0.919703901, 'Generosity': None, 'Perceptions of corruption': None, 'Confidence in national government': 0.376573861}, {'Unnamed: 0': 5, 'Country': 'Austria', 'Year': 2013, 'Score': 7.498802662, 'GDP': 10.69280529, 'Social support': 0.9498091940000001, 'Healthy life expectancy': 70.90379333, 'Freedom': 0.921734452, 'Generosity': None, 'Perceptions of corruption': None, 'Confidence in national government': 0.417099237}, {'Unnamed: 0': 6, 'Country': 'Austria', 'Year': 2014, 'Score': 6.9499998089999995, 'GDP': 10.68985462, 'Social support': 0.8989204759999999, 'Healthy life expectancy': 70.86317444, 'Freedom': 0.8850268720000001, 'Generosity': None, 'Perceptions of corruption': None, 'Confidence in national government': 0.40769541299999995}, {'Unnamed: 0': 7, 'Country': 'Austria', 'Year': 2015, 'Score': 7.07644701, 'GDP': 10.6913538, 'Social support': 0.9281103009999999, 'Healthy life expectancy': 70.82255554, 'Freedom': 0.900305152, 'Generosity': None, 'Perceptions of corruption': None, 'Confidence in national government': 0.454789877}  ... displaying 10 of 124 total bound parameter sets ...  {'Unnamed: 0': 122, 'Country': 'Italy', 'Year': 2018, 'Score': 6.0, 'GDP': 1.264, 'Social support': 1.501, 'Healthy life expectancy': 0.946, 'Freedom': 0.281, 'Generosity': 0.13699999999999998, 'Perceptions of corruption': 0.027999999999999997, 'Confidence in national government': None}, {'Unnamed: 0': 123, 'Country': 'Greece', 'Year': 2018, 'Score': 5.358, 'GDP': 1.1540000000000001, 'Social support': 1.202, 'Healthy life expectancy': 0.879, 'Freedom': 0.131, 'Generosity': 0.0, 'Perceptions of corruption': 0.044000000000000004, 'Confidence in national government': None})]
# (Background on this error at: http://sqlalche.me/e/2j85)

# %%
elections.to_sql("elections", con=engine, if_exists="append", index=False)
#engine.execute("SELECT * FROM elections").fetchall()

# %%
#First we need a simple dataframe with the years that we ll use
year.to_sql("year", con=engine, index=False)

# %%
#First we need a smple dataframe with the countries chosen
country.to_sql("country", con=engine, index=False)
